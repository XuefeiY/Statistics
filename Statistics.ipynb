# %% [markdown]
# 1. type 1 error is rejecting the null hypothesis when its actually true
# 2. type 2 error is accepting the null hypothesis when its actually false
# 3. confidence interval
# 4. p value
# 5. z test: Z-test implies a hypothesis test which ascertains if the means of two datasets are different from each other when variance is given.
# 6. t test: T-test refers to a univariate hypothesis test based on t-statistic, wherein the mean is known, and population variance is approximated from the sample.
# 7. f test
# 8. covariance
# 9. correlation: pearson, spearman
# 10. independent
# 11. r square
# 12. significance level
# 13. power
# 14. chi square test
# 15. ANOVA

# %%
from IPython.display import Image
Image(filename='z test & t test.png')

# %%
from IPython.display import Image
Image(filename='Common Statistical Test.png')

# %% [markdown]
# Recap:
#
# https://www.analyticsvidhya.com/blog/2017/05/41-questions-on-statisitics-data-scientists-analysts/
